# %%
# %cd ~/theory_nn
# !git pull origin main
# %cd california_housing

from src import dataset, scaler, regressor
import matplotlib.pyplot as plt
# Out:
# /root/theory_nn
# From https://github.com/RudenkoBogdan/theory_nn
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# /root/theory_nn/california_housing

# %%
data = dataset.Data()
scaler = scaler.Scaler()
X_train, X_test, y_train, y_test = data.split()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = regressor.Regressor()
nn_history = model.fit(X_train, y_train)
# Out:
# ========
# Epoch 0
# Loss 5.0596763157794795
# ========
# Epoch 50
# Loss 1.1821728856015734
# ========
# Epoch 100
# Loss 0.9515707151695763
# ========
# Epoch 150
# Loss 0.8713760842716417
# ========
# Epoch 200
# Loss 0.8329774607457989
# ========
# Epoch 250
# Loss 0.8088156082295015
# ========
# Epoch 300
# Loss 0.7902147482584799
# ========
# Epoch 350
# Loss 0.7741549565914742
# ========
# Epoch 400
# Loss 0.7596842078608802
# ========
# Epoch 450
# Loss 0.7463763061433788
# ========
# Epoch 500
# Loss 0.7340041033339568
# ========
# Epoch 550
# Loss 0.7224511317091579
# ========
# Epoch 600
# Loss 0.7116248861635709
# ========
# Epoch 650
# Loss 0.7014251181701109
# ========
# Epoch 700
# Loss 0.6917950749903465
# ========
# Epoch 750
# Loss 0.6826833133675527
# ========
# Epoch 800
# Loss 0.6740367839701736
# ========
# Epoch 850
# Loss 0.6658034562799732
# ========
# Epoch 900
# Loss 0.6579647220849173
# ========
# Epoch 950
# Loss 0.6504934524908166
# ========
# Epoch 1000
# Loss 0.6433712946422981
# ========
# Epoch 1050
# Loss 0.6365455227182263
# ========
# Epoch 1100
# Loss 0.6299884008865904
# ========
# Epoch 1150
# Loss 0.6236644857110771
# ========
# Epoch 1200
# Loss 0.6175644578325516
# ========
# Epoch 1250
# Loss 0.611672427490941
# ========
# Epoch 1300
# Loss 0.6059731720786495
# ========
# Epoch 1350
# Loss 0.6004742882559085
# ========
# Epoch 1400
# Loss 0.595168966540962
# ========
# Epoch 1450
# Loss 0.5900479536956547
# ========
# Epoch 1500
# Loss 0.5851031218638293
# ========
# Epoch 1550
# Loss 0.5803217495686415
# ========
# Epoch 1600
# Loss 0.575688219301685
# ========
# Epoch 1650
# Loss 0.5711944812229653
# ========
# Epoch 1700
# Loss 0.5668484457415598
# ========
# Epoch 1750
# Loss 0.5626382910986691
# ========
# Epoch 1800
# Loss 0.5585642939611482
# ========
# Epoch 1850
# Loss 0.5546093856878576
# ========
# Epoch 1900
# Loss 0.550762837967057
# ========
# Epoch 1950
# Loss 0.547027874943576

# %%
import matplotlib.pyplot as plt

plt.plot(range(len(model.history)), model.history)
