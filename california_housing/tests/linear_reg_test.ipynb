# %%
# %cd ~/theory_nn
# !git pull origin main
# %cd california_housing

from src import dataset, scaler, linear_regression
import matplotlib.pyplot as plt
# Out:
# /root/theory_nn
# From https://github.com/RudenkoBogdan/theory_nn
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# /root/theory_nn/california_housing

# %%
data = dataset.Data()
scaler = scaler.Scaler()
LR = linear_regression.LinearRegression()

# %%
X_train, X_test, y_train, y_test = data.split()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

history = LR.fit(X_train, y_train)

# %%
plt.plot(range(len(history)), history)
